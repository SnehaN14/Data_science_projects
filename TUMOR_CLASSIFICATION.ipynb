# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Pandas and NumPy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("tumor.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
df.drop('Unnamed: 32', axis=1, inplace=True)

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# 883263       1
# 906564       1
# 89122        1
# 9013579      1
# 868682       1
# 859465       1
# 859464       1
# 911685       1
# 895299       1
# 909220       1
# 8811842      1
# 916799       1
# 901034302    1
# 901034301    1
# 8911164      1
# 869691       1
# 8812877      1
# 859471       1
# 911673       1
# 87281702     1
# 85638502     1
# 91762702     1
# 859487       1
# 857438       1
# 91485        1
# 903516       1
# 9013594      1
# 914769       1
# 8611161      1
# 9012568      1
#             ..
# 864496       1
# 88143502     1
# 91789        1
# 894604       1
# 907914       1
# 89346        1
# 8912521      1
# 868999       1
# 921362       1
# 894335       1
# 903811       1
# 8711561      1
# 925311       1
# 907915       1
# 869224       1
# 852631       1
# 894618       1
# 909410       1
# 8511133      1
# 916838       1
# 8910499      1
# 891936       1
# 913063       1
# 89827        1
# 8910506      1
# 874158       1
# 914062       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df_categorical2 = df.select_dtypes(include=['int64','float64'])
df_categorical2.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
df_categorical2.drop('id', axis=1, inplace=True)

# %%
df_categorical2.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean           ...             radius_worst  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
nc_columns=list(df_categorical2.columns)

# %%
df_categorical2[nc_columns] = scaler.fit_transform(df_categorical2[nc_columns])

# %%
df_categorical2.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.521037      0.022658        0.545989   0.363733         0.593753
# 1     0.643144      0.272574        0.615783   0.501591         0.289880
# 2     0.601496      0.390260        0.595743   0.449417         0.514309
# 3     0.210090      0.360839        0.233501   0.102906         0.811321
# 4     0.629893      0.156578        0.630986   0.489290         0.430351
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          0.792037        0.703140             0.731113       0.686364
# 1          0.181768        0.203608             0.348757       0.379798
# 2          0.431017        0.462512             0.635686       0.509596
# 3          0.811361        0.565604             0.522863       0.776263
# 4          0.347893        0.463918             0.518390       0.378283
#
#    fractal_dimension_mean           ...             radius_worst  \
# ...

# %%
df.drop('id',axis=1, inplace=True)

# %%
df.drop(nc_columns, axis=1, inplace=True)

# %%
df.head()
# Out:
#   diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M

# %%
final_df= pd.concat([df,df_categorical2], axis=1)

# %%
final_df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M     0.521037      0.022658        0.545989   0.363733
# 1         M     0.643144      0.272574        0.615783   0.501591
# 2         M     0.601496      0.390260        0.595743   0.449417
# 3         M     0.210090      0.360839        0.233501   0.102906
# 4         M     0.629893      0.156578        0.630986   0.489290
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         0.593753          0.792037        0.703140             0.731113
# 1         0.289880          0.181768        0.203608             0.348757
# 2         0.514309          0.431017        0.462512             0.635686
# 3         0.811321          0.811361        0.565604             0.522863
# 4         0.430351          0.347893        0.463918             0.518390
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
final_df['diagnosis'] = df['diagnosis'].apply({'B':0, 'M':1}.get)
final_df['diagnosis'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: diagnosis, dtype: int64

# %%
# Importing test_train_split from sklearn library
from sklearn.model_selection import train_test_split
y=final_df["diagnosis"]
X=final_df.drop(['diagnosis'],axis=1)

# %%
#Splitting data into train and test data
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size = 0.7, test_size= 0.3, random_state = 100)

# %%
#Running Your First Training Model
import statsmodels.api as sm

# %%
# Logistic regression model
logm1 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
#logm1.fit().summary()

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
from sklearn.feature_selection import RFE
rfe = RFE(logreg, 10)             # running RFE with 15 variables as output
rfe = rfe.fit(X_train,y_train)

# %%
list(zip(X_train.columns, rfe.support_, rfe.ranking_))
# Out:
# [('radius_mean', False, 10),
#  ('texture_mean', False, 8),
#  ('perimeter_mean', False, 3),
#  ('area_mean', True, 1),
#  ('smoothness_mean', False, 17),
#  ('compactness_mean', False, 14),
#  ('concavity_mean', True, 1),
#  ('concave points_mean', True, 1),
#  ('symmetry_mean', False, 16),
#  ('fractal_dimension_mean', True, 1),
#  ('radius_se', True, 1),
#  ('texture_se', False, 19),
#  ('perimeter_se', False, 4),
#  ('area_se', False, 7),
#  ('smoothness_se', False, 18),
#  ('compactness_se', False, 5),
#  ('concavity_se', False, 15),
#  ('concave points_se', False, 20),
#  ('symmetry_se', False, 12),
#  ('fractal_dimension_se', False, 11),
#  ('radius_worst', True, 1),
#  ('texture_worst', True, 1),
#  ('perimeter_worst', True, 1),
#  ('area_worst', True, 1),
#  ('smoothness_worst', False, 9),
#  ('compactness_worst', False, 6),
#  ('concavity_worst', False, 2),
#  ('concave points_worst', True, 1),
#  ('symmetry_worst', False, 13),
#  ('fractal_dimension_worst', False, 21)]

# %%
col = X_train.columns[rfe.support_]

# %%
X_train_sm=sm.add_constant(X_train[col])
logm2 = sm.GLM(y_train,X_train_sm, family = sm.families.Binomial())
modres = logm2.fit()
logm2.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:              diagnosis   No. Observations:                  398
# Model:                            GLM   Df Residuals:                      387
# Model Family:                Binomial   Df Model:                           10
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                    nan
# Date:                Sat, 23 Nov 2019   Deviance:                          nan
# Time:                        23:40:12   Pearson chi2:                     81.7
# No. Iterations:                   100   Covariance Type:             nonrobust
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
#predicted  values
# Getting the predicted values on the train set
y_train_pred = modres.predict(X_train_sm)
y_train_pred[:10]
# Out:
# 18     1.000000e+00
# 213    7.441974e-01
# 532    1.159350e-04
# 191    4.896666e-03
# 235    1.448662e-03
# 471    2.972523e-01
# 485    3.725525e-03
# 153    8.734058e-07
# 357    5.004406e-05
# 412    3.350608e-07
# dtype: float64

# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import scale

# %%
# using rbf kernel, C=1, default value of gamma
#try  SVM
model = SVC(C = 1, kernel='rbf')
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
# accuracy
print("accuracy", metrics.accuracy_score(y_test, y_pred))

# precision
print("precision", metrics.precision_score(y_test, y_pred))

# recall/sensitivity
print("recall", metrics.recall_score(y_test, y_pred))
# Out:
# accuracy 0.9298245614035088
# precision 1.0
# recall 0.8260869565217391
